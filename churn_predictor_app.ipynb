# %%
import streamlit as st
import pandas as pd
import numpy as np
import joblib 
from collections import OrderedDict

MODEL_FILE = 'xgboost_classifier_churn_model.joblib'
# NOTE: If you saved your StandardScaler object, uncomment and update this line:
# SCALER_FILE = 'standard_scaler.joblib' 

# CRITICAL FIX: The FEATURE_COLUMNS list MUST exactly match the order the model expects.
# This list is derived directly from the 'Model Expected Features' in your ValueError traceback.
FEATURE_COLUMNS = [
    'Tenure_Months', 
    'Monthly_Charges_ETB', 
    'Support_Calls_3Months', 
    'Network_Outage_Score_0_5', 
    'Total_Charges_ETB',
    # --- CORRECTED ORDER ---
    'Region_Regional City (Mid Density)', 
    'Region_Rural Area (Low Density)', 
    'Contract_Type_24-Month', 
    'Contract_Type_6-Month', 
    'Contract_Type_Month-to-month', 
    'Service_Plan_Data/Internet + Voice', 
    'Service_Plan_Premium Bundle (Data, telebirr, VAS)',
    'Network_Technology_3G', 
    'Network_Technology_4G/LTE', 
    'Network_Technology_5G'
]

@st.cache_resource # Caches the model so it loads only once
def load_assets():
    """Loads the trained model and scaler."""
    try:
        model = joblib.load(MODEL_FILE)
        # If you saved a scaler, load it here:
        # scaler = joblib.load(SCALER_FILE)
        return model #, scaler 
    except FileNotFoundError:
        st.error(f"Error: Model file '{MODEL_FILE}' not found. Ensure it's in the correct directory.")
        st.stop()
    except Exception as e:
        st.error(f"Error loading model: {e}")
        st.stop()

# Load the model (and scaler if applicable)
model = load_assets() #, scaler

# --- Streamlit Application Setup ---

st.set_page_config(
    page_title="Ethio Telecom Churn Risk Analyzer",
    layout="wide",
    initial_sidebar_state="expanded"
)

# Custom Styling
st.markdown("""
<style>
    .stButton>button {
        background-color: #00A651; /* Ethio Telecom Green */
        color: white;
        font-weight: bold;
        padding: 10px 20px;
        border-radius: 8px;
    }
    .risk-high {
        background-color: #FFC0CB; /* Light Pink for High Risk */
        padding: 15px;
        border-radius: 10px;
        border-left: 5px solid #E60000; /* Red Border */
        font-size: 18px;
        font-weight: bold;
    }
    .risk-low {
        background-color: #E6FFE6; /* Light Green for Low Risk */
        padding: 15px;
        border-radius: 10px;
        border-left: 5px solid #00CC00; /* Green Border */
        font-size: 18px;
        font-weight: bold;
    }
</style>
""", unsafe_allow_html=True)

st.title("🇪🇹 Ethio Telecom Churn Risk Analyzer")
st.markdown("---")

# --- Sidebar for Inputs (REORDERED BY IMPORTANCE) ---
with st.sidebar:
    st.header("Customer Profile Input")
    st.markdown("Adjust the variables to assess the churn risk.")
    st.markdown("---")

    # 1. CRITICAL SERVICE QUALITY (Ranks #1 & #4)
    st.subheader("1. Service & Support (Highest Impact)")
    
    # Network Outage Score (Rank #1)
    outage_score = st.slider(
        "Network Outage/Reliability Score (0-5)", 
        0, 5, 1, 
        help="Feature Importance Rank #1. 5 indicates severe, frequent outages."
    )
    
    # Support Calls (Rank #4)
    support_calls = st.slider("Support Calls (Last 3 Months)", 0, 10, 1, help="Feature Importance Rank #4. High call volume indicates frustration.")

    st.markdown("---")
    
    # 2. INFRASTRUCTURE & LOCATION (Ranks #2, #3, #5)
    st.subheader("2. Infrastructure & Location (High Impact)")

    # Region (Rank #2 & #3)
    region = st.selectbox(
        "Customer Region", 
        ['Addis Ababa (Base)', 'Regional City (Mid Density)', 'Rural Area (Low Density)'],
        index=0,
        help="Feature Importance Rank #2 & #3. Regional/Rural areas are significantly higher risk."
    )
    
    # Technology (Rank #5)
    network_tech = st.selectbox(
        "Network Technology Used",
        ['5G/4G (Base)', '3G', '2G Only'],
        index=0,
        help="Older technology (3G/2G) correlates with higher churn."
    )

    st.markdown("---")
    
    # 3. COMMERCIAL & CONTRACT (Medium Impact)
    st.subheader("3. Commercial & Contract Details")

    # Contract Type (Rank #7-9)
    contract = st.selectbox(
        "Contract Type",
        ['12-Month (Base)', '24-Month', '6-Month', 'Month-to-month'],
        index=0,
        help="6-Month and Month-to-month contracts carry more risk."
    )
    
    # Monthly Charges & Tenure
    monthly_charges = st.number_input("Monthly Charges (ETB)", 100.0, 3000.0, 550.0, step=50.0)
    tenure = st.slider("Tenure (Months)", 1, 84, 12)

    # Service Plan
    service_plan = st.selectbox(
        "Service Plan",
        ['Basic Mobile Voice (Base)', 'Data/Internet + Voice', 'Premium Bundle (Data, telebirr, VAS)'],
        index=0
    )


# --- Main Content Area for Prediction ---

st.header("1. Churn Prediction Result")

if st.button("Analyze Risk"):
    
    # 1. Prepare Feature Vector (Use OrderedDict to ensure keys are processed consistently)
    input_features = OrderedDict({col: 0 for col in FEATURE_COLUMNS})
    
    # Populate numerical/ordinal features
    input_features['Tenure_Months'] = tenure
    input_features['Monthly_Charges_ETB'] = monthly_charges
    input_features['Support_Calls_3Months'] = support_calls
    input_features['Network_Outage_Score_0_5'] = outage_score
    input_features['Total_Charges_ETB'] = monthly_charges * tenure
    
    # Populate categorical/OHE features
    # Region
    if region == 'Regional City (Mid Density)':
        input_features['Region_Regional City (Mid Density)'] = 1
    elif region == 'Rural Area (Low Density)':
        input_features['Region_Rural Area (Low Density)'] = 1

    # Contract
    if contract == 'Month-to-month':
        input_features['Contract_Type_Month-to-month'] = 1
    elif contract == '6-Month':
        input_features['Contract_Type_6-Month'] = 1
    elif contract == '24-Month':
        input_features['Contract_Type_24-Month'] = 1
        
    # Network Technology
    if network_tech == '3G':
        input_features['Network_Technology_3G'] = 1
    elif network_tech == '4G/LTE':
        input_features['Network_Technology_4G/LTE'] = 1
    elif network_tech == '5G/4G (Base)': # If 4G/5G is selected, set 5G to 1 as the primary modern tech.
         input_features['Network_Technology_5G'] = 1

    # Service Plan
    if service_plan == 'Data/Internet + Voice':
        input_features['Service_Plan_Data/Internet + Voice'] = 1
    elif service_plan == 'Premium Bundle (Data, telebirr, VAS)':
        input_features['Service_Plan_Premium Bundle (Data, telebirr, VAS)'] = 1
        
    # Convert to DataFrame in the exact order enforced by FEATURE_COLUMNS list
    input_df = pd.DataFrame([input_features])
    input_df = input_df[FEATURE_COLUMNS] 

    # 2. Scaling (Uncomment if you saved and loaded a scaler)
    # input_df[numerical_cols] = scaler.transform(input_df[numerical_cols])

    # 3. Predict
    prediction = model.predict(input_df)[0] 
    probability = model.predict_proba(input_df)[:, 1][0] 

    # 4. Display Results
    if prediction == 1:
        st.markdown(f"""
        <div class="risk-high">
            🚨 HIGH CHURN RISK
            <p style='font-size:16px; margin-top:5px;'>Predicted Churn Probability: <b>{probability:.1%}</b></p>
        </div>
        """, unsafe_allow_html=True)
        st.error("ACTION REQUIRED: This customer is flagged by the XGBoost model as high risk.")
    else:
        st.markdown(f"""
        <div class="risk-low">
            ✅ LOW CHURN RISK
            <p style='font-size:16px; margin-top:5px;'>Predicted Churn Probability: <b>{probability:.1%}</b></p>
        </div>
        """, unsafe_allow_html=True)
        st.success("Monitoring recommended, but immediate retention effort is not necessary.")

    st.markdown("---")
    
    # --- Actionable Insights based on Prediction ---
    st.header("2. Targeted Retention Strategy")
    st.markdown("**Intervention Plan based on High-Impact Features:**")
    
    if prediction == 1:
        if outage_score >= 3:
            st.warning("⚠️ **Service Quality Trigger (Rank #1):** High Network Outage Score is the primary driver. **Action:** Proactive credit/data bonus to acknowledge and compensate for service disruption.")
        
        if region != 'Addis Ababa (Base)':
            st.warning("🏘️ **Geographical Trigger (Rank #2/3):** Location contributes significantly to risk.")
            st.markdown("- **Action:** Offer **subsidized 4G device/data package** tied to a 12-month contract to address regional infrastructure concerns.")
            
        if support_calls >= 3:
            st.warning("📞 **Support Frustration Trigger (Rank #4):** High call volume indicates unresolved issues.")
            st.markdown("- **Action:** Escalate to the **senior retention team** for personal follow-up and definitive resolution.")
            
        if contract in ['6-Month', 'Month-to-month']:
            st.info("🤝 **Contract Trigger:** Short-term contract increases risk.")
            st.markdown("- **Action:** Offer a strong value incentive to upgrade to a stable 12-Month or 24-Month contract.")
    else:
        st.info("No immediate retention action required. Continue monitoring. Focus resources on high-risk customers.")

# --- Footer: Project and Model Information ---
st.sidebar.markdown("---")
st.sidebar.caption("Project: Ethio Telecom Churn Analysis")
st.sidebar.caption(f"Model: XGBoost Classifier (Loaded from {MODEL_FILE})")
# Out:
# 2025-10-07 11:31:30.433 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:31:34.455
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\AKE\Desktop\telecom\venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-10-07 11:31:34.457 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:31:34.459 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:31:34.462 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:31:34.966 Thread 'Thread-3': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:31:34.966 Thread 'Thread-3': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:31:34.982 Thread 'Thread-3': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.321 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.353 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.356 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.360 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.365 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.365 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.365 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.365 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.382 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.387 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.390 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.393 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.397 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.416 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.432 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.437 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.452 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.452 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.469 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.471 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.473 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.476 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.484 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.488 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.496 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.504 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.507 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.509 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.517 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.524 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.526 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.535 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.540 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.567 Session state does not function when running a script without `streamlit run`
# 2025-10-07 11:32:04.570 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.575 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.577 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.580 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.582 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.584 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.587 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.595 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.596 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.598 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.602 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.616 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.633 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.636 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.639 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.643 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.656 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.659 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.661 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.662 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.669 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.690 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.696 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.703 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.705 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.707 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.711 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.717 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.724 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.727 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-07 11:32:04.734 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator(_root_container=1, _parent=DeltaGenerator())
